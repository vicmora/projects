# %%
import cfg
from nytimesarticle import articleAPI
search_api = articleAPI(cfg.NYT_SEARCH_TOKEN)

# %%
articles = search_api.search( q = 'Obama',
                      fq = {'headline':'Obama', 'source':['Reuters','AP', 'The New York Times']},
                      begin_date = 20111231 )

# %%
articles
# Out:
# {u'copyright': u'Copyright (c) 2013 The New York Times Company.  All Rights Reserved.',
#  u'response': {u'docs': [{u'_id': u'57776e4d38f0d81f396c0545',
#     u'abstract': None,
#     u'blog': [],
#     u'byline': {u'original': u'By MICHAEL D. SHEAR',
#      u'person': [{u'firstname': u'Michael',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'}]},
#     u'document_type': u'article',
#     u'headline': {u'main': u'Obama After Dark: The Precious Hours Alone',
#      u'print_headline': u'Obama at Night: 7 Almonds and Some Precious Solitude'},
#     u'keywords': [{u'is_major': u'N',
#       u'name': u'persons',
#       u'rank': u'1',
#       u'value': u'Obama, Barack'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'2',
#       u'value': u'United States Politics and Government'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'3',
#       u'value': u'White House Building (Washington, DC)'}],
#     u'lead_paragraph': u'President Obama has come to consider the solitary hours after dark as essential as his time in the Oval Office. Barely getting five hours of sleep a night, he considers the time alone more important.',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2016/06/26/us/27obama-web1/27obama-web1-thumbWide-v2.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2016/06/26/us/27obama-web1/27obama-web1-thumbWide-v2.jpg',
#       u'width': 190},
#      {u'height': 400,
#       u'legacy': {u'xlarge': u'images/2016/06/26/us/27obama-web1/27obama-web1-articleLarge.jpg',
#        u'xlargeheight': u'400',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2016/06/26/us/27obama-web1/27obama-web1-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2016/06/26/us/27obama-web1/27obama-web1-thumbStandard.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2016/06/26/us/27obama-web1/27obama-web1-thumbStandard.jpg',
#       u'width': 75}],
#     u'news_desk': u'National',
#     u'print_page': u'1',
#     u'pub_date': u'2016-07-03T00:00:00Z',
#     u'section_name': u'U.S.',
#     u'slideshow_credits': None,
#     u'snippet': u'President Obama has come to consider the solitary hours after dark as essential as his time in the Oval Office. Barely getting five hours of sleep a night, he considers the time alone more important.',
#     u'source': u'The New York Times',
#     u'subsection_name': u'Politics',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/2016/07/03/us/politics/obama-after-dark-the-precious-hours-alone.html',
#     u'word_count': u'1825'},
#    {u'_id': u'5775966f38f0d87c9d837961',
#     u'abstract': u'Tod Williams and Billie Tsien, husband-and-wife modernist architecture team known for work on prominent cultural institutions, are selected to design Barack H Obama Presidential Library and Museum in Chicago.',
#     u'blog': [],
#     u'byline': {u'original': u'By JULIE HIRSCHFELD DAVIS',
#      u'person': [{u'firstname': u'Julie',
#        u'lastname': u'DAVIS',
#        u'middlename': u'Hirschfeld',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'}]},
#     u'document_type': u'article',
#     u'headline': {u'main': u'Obama Picks New York Architects to Design Presidential Library',
#      u'print_headline': u'Obama Picks Architects Based in New York to Design Presidential Library'},
#     u'keywords': [{u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'1',
#       u'value': u'Architecture'},
#      {u'is_major': u'N',
#       u'name': u'glocations',
#       u'rank': u'11',
#       u'value': u'United States'},
#      {u'is_major': u'Y',
#       u'name': u'glocations',
#       u'rank': u'2',
#       u'value': u'Chicago (Ill)'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'3',
#       u'value': u'United States Politics and Government'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'4',
#       u'value': u'Libraries and Librarians'},
#      {u'is_major': u'N',
#       u'name': u'organizations',
#       u'rank': u'5',
#       u'value': u'Obama, Barack H, Foundation'},
#      {u'is_major': u'Y',
#       u'name': u'organizations',
#       u'rank': u'6',
#       u'value': u'Obama, Barack H, Presidential Library and Museum'},
#      {u'is_major': u'N',
#       u'name': u'persons',
#       u'rank': u'7',
#       u'value': u'Obama, Barack'},
#      {u'is_major': u'N',
#       u'name': u'persons',
#       u'rank': u'8',
#       u'value': u'Obama, Michelle'},
#      {u'is_major': u'Y',
#       u'name': u'persons',
#       u'rank': u'9',
#       u'value': u'Tsien, Billie'},
#      {u'is_major': u'Y',
#       u'name': u'persons',
#       u'rank': u'10',
#       u'value': u'Williams, Tod'}],
#     u'lead_paragraph': u'The president and his wife, Michelle, spent months poring over proposals for the project and meeting with prospective architects at the White House',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2016/07/01/us/01OBAMA/01OBAMA-thumbWide.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2016/07/01/us/01OBAMA/01OBAMA-thumbWide.jpg',
#       u'width': 190},
#      {u'height': 431,
#       u'legacy': {u'xlarge': u'images/2016/07/01/us/01OBAMA/01OBAMA-articleLarge.jpg',
#        u'xlargeheight': u'431',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2016/07/01/us/01OBAMA/01OBAMA-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2016/07/01/us/01OBAMA/01OBAMA-thumbStandard.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2016/07/01/us/01OBAMA/01OBAMA-thumbStandard.jpg',
#       u'width': 75}],
#     u'news_desk': u'National',
#     u'print_page': u'16',
#     u'pub_date': u'2016-07-01T00:00:00Z',
#     u'section_name': u'U.S.',
#     u'slideshow_credits': None,
#     u'snippet': u'The president and his wife, Michelle, spent months poring over proposals for the project and meeting with prospective architects at the White House',
#     u'source': u'The New York Times',
#     u'subsection_name': u'Politics',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/2016/07/01/us/politics/obama-picks-new-york-architects-to-design-presidential-library.html',
#     u'word_count': u'635'},
#    {u'_id': u'5770517038f0d8170405485f',
#     u'abstract': u'White House Letter; Pres Obama relishes opportunity to host Cleveland Cavaliers, 2016 NBA champions, before he leaves office in January; admits welcoming championship sports teams to White House is one of his favorite presidential duties. ',
#     u'blog': [],
#     u'byline': {u'original': u'By GARDINER HARRIS',
#      u'person': [{u'firstname': u'Gardiner',
#        u'lastname': u'HARRIS',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'}]},
#     u'document_type': u'article',
#     u'headline': {u'content_kicker': u'White House Letter',
#      u'kicker': u'White House Letter',
#      u'main': u'Cleveland Cavaliers Join Obama\u2019s To-Do List. He Loves This Part of the Job.',
#      u'print_headline': u'Obama Puts Cleveland\u2019s New Champions on a Favorite To-Do List'},
#     u'keywords': [{u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'1',
#       u'value': u'Athletics and Sports'},
#      {u'is_major': u'Y',
#       u'name': u'persons',
#       u'rank': u'2',
#       u'value': u'Obama, Barack'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'3',
#       u'value': u'Basketball'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'4',
#       u'value': u'Presidents and Presidency (US)'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'5',
#       u'value': u'White House Building (Washington, DC)'},
#      {u'is_major': u'N',
#       u'name': u'glocations',
#       u'rank': u'6',
#       u'value': u'Washington (DC)'},
#      {u'is_major': u'Y',
#       u'name': u'organizations',
#       u'rank': u'7',
#       u'value': u'Cleveland Cavaliers'}],
#     u'lead_paragraph': u'Welcoming championship sports teams to the White House has been one of President Obama\u2019s favorite tasks. It might have even challenged the pleasures of Air Force One \u2014 if every winner had come from Chicago.',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2016/06/27/us/27whletter-web1/27whletter-web1-thumbWide.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2016/06/27/us/27whletter-web1/27whletter-web1-thumbWide.jpg',
#       u'width': 190},
#      {u'height': 400,
#       u'legacy': {u'xlarge': u'images/2016/06/27/us/27whletter-web1/27whletter-web1-articleLarge.jpg',
#        u'xlargeheight': u'400',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2016/06/27/us/27whletter-web1/27whletter-web1-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2016/06/27/us/27whletter-web1/27whletter-web1-thumbStandard.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2016/06/27/us/27whletter-web1/27whletter-web1-thumbStandard.jpg',
#       u'width': 75}],
#     u'news_desk': u'National',
#     u'print_page': u'14',
#     u'pub_date': u'2016-06-27T00:00:00Z',
#     u'section_name': u'U.S.',
#     u'slideshow_credits': None,
#     u'snippet': u'Welcoming championship sports teams to the White House has been one of President Obama\u2019s favorite tasks. It might have even challenged the pleasures of Air Force One \u2014 if every winner had come from Chicago.',
#     u'source': u'The New York Times',
#     u'subsection_name': u'Politics',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/2016/06/27/us/politics/cleveland-cavaliers-join-obamas-to-do-list-he-loves-this-part-of-the-job.html',
#     u'word_count': u'1085'},
#    {u'_id': u'576bf65238f0d83413c93fa4',
#     u'abstract': u"Supreme Court deadlocks 4-4 to leave in place appeals court ruling blocking Pres Obama's ambitious plan to shield undocumented immigrants from deportation; nine-word ruling ruling will have many consequences, and is likely to intensify debate over nation's immigration policy and presidential authority.  ",
#     u'blog': [],
#     u'byline': {u'contributor': u'',
#      u'original': u'By ADAM LIPTAK and MICHAEL D. SHEAR',
#      u'person': [{u'firstname': u'Adam',
#        u'lastname': u'LIPTAK',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'},
#       {u'firstname': u'Michael',
#        u'organization': u'',
#        u'rank': 2,
#        u'role': u'reported'}]},
#     u'document_type': u'article',
#     u'headline': {u'main': u'Supreme Court Tie Blocks Obama Immigration Plan',
#      u'print_headline': u'Split Court Stifles Obama on Immigration'},
#     u'keywords': [{u'is_major': u'Y',
#       u'name': u'organizations',
#       u'rank': u'1',
#       u'value': u'Supreme Court (US)'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'2',
#       u'value': u'Immigration and Emigration'},
#      {u'is_major': u'Y',
#       u'name': u'persons',
#       u'rank': u'3',
#       u'value': u'Obama, Barack'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'4',
#       u'value': u'Law and Legislation'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'5',
#       u'value': u'Deportation'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'6',
#       u'value': u'Illegal Immigration'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'7',
#       u'value': u'Decisions and Verdicts'},
#      {u'is_major': u'N',
#       u'name': u'glocations',
#       u'rank': u'8',
#       u'value': u'Texas'}],
#     u'lead_paragraph': u'The 4-4 tie dealt a sharp blow to an ambitious program that the president had hoped would become one of his central legacies.',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2016/06/24/us/24immig-web-sub/24immig-web-sub-thumbWide.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2016/06/24/us/24immig-web-sub/24immig-web-sub-thumbWide.jpg',
#       u'width': 190},
#      {u'height': 399,
#       u'legacy': {u'xlarge': u'images/2016/06/24/us/24immig-web-sub/24immig-web-sub-articleLarge.jpg',
#        u'xlargeheight': u'399',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2016/06/24/us/24immig-web-sub/24immig-web-sub-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2016/06/24/us/24immig-web-sub/24immig-web-sub-thumbStandard.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2016/06/24/us/24immig-web-sub/24immig-web-sub-thumbStandard.jpg',
#       u'width': 75}],
#     u'news_desk': u'National',
#     u'print_page': u'1',
#     u'pub_date': u'2016-06-24T00:00:00Z',
#     u'section_name': u'U.S.',
#     u'slideshow_credits': None,
#     u'snippet': u'The 4-4 tie dealt a sharp blow to an ambitious program that the president had hoped would become one of his central legacies.',
#     u'source': u'The New York Times',
#     u'subsection_name': None,
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/2016/06/24/us/supreme-court-immigration-obama-dapa.html',
#     u'word_count': u'1424'},
#    {u'_id': u'5776b13138f0d81f396c03c5',
#     u'abstract': None,
#     u'blog': [],
#     u'byline': [],
#     u'document_type': u'article',
#     u'headline': {u'content_kicker': u'Letters',
#      u'kicker': u'Letters',
#      u'main': u'Obama as the First Black President',
#      u'print_headline': u'Obama as the First Black President'},
#     u'keywords': [{u'is_major': u'N',
#       u'name': u'persons',
#       u'rank': u'1',
#       u'value': u'Obama, Barack'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'2',
#       u'value': u'Blacks'}],
#     u'lead_paragraph': u'Readers disagree with a Sunday Review writer who said the president failed to do enough to address race issues and \u201clessen black suffering.\u201d',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2016/07/02/opinion/02Lobama-web/02Lobama-web-thumbWide.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2016/07/02/opinion/02Lobama-web/02Lobama-web-thumbWide.jpg',
#       u'width': 190},
#      {u'height': 394,
#       u'legacy': {u'xlarge': u'images/2016/07/02/opinion/02Lobama-web/02Lobama-web-articleLarge.jpg',
#        u'xlargeheight': u'394',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2016/07/02/opinion/02Lobama-web/02Lobama-web-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2016/07/02/opinion/02Lobama-web/02Lobama-web-thumbStandard.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2016/07/02/opinion/02Lobama-web/02Lobama-web-thumbStandard.jpg',
#       u'width': 75}],
#     u'news_desk': u'Letters',
#     u'print_page': u'16',
#     u'pub_date': u'2016-07-02T00:00:00Z',
#     u'section_name': u'Opinion',
#     u'slideshow_credits': None,
#     u'snippet': u'Readers disagree with a Sunday Review writer who said the president failed to do enough to address race issues and \u201clessen black suffering.\u201d',
#     u'source': u'The New York Times',
#     u'subsection_name': None,
#     u'type_of_material': u'Letter',
#     u'web_url': u'http://www.nytimes.com/2016/07/02/opinion/obama-as-the-first-black-president.html',
#     u'word_count': u'588'},
#    {u'_id': u'5763eab438f0d83da36e0716',
#     u'abstract': u"Pres Obama vacations with his family in Yosemite National Park, where they visit Carlsbad Caverns; series of Obama family vacations to national parks are intended to highlight benefits of protecting wilderness land, part of Obama administration's legacy on conservation.",
#     u'blog': [],
#     u'byline': {u'original': u'By GARDINER HARRIS',
#      u'person': [{u'firstname': u'Gardiner',
#        u'lastname': u'HARRIS',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'}]},
#     u'document_type': u'article',
#     u'headline': {u'main': u'President Obama and Family Tour \u2018Cool\u2019 Carlsbad Caverns',
#      u'print_headline': u'President and Family Tour \u2018Cool\u2019 Carlsbad Caverns'},
#     u'keywords': [{u'is_major': u'Y',
#       u'name': u'persons',
#       u'rank': u'1',
#       u'value': u'Obama, Barack'},
#      {u'is_major': u'Y',
#       u'name': u'glocations',
#       u'rank': u'2',
#       u'value': u'Yosemite National Park (Calif)'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'3',
#       u'value': u'National Parks, Monuments and Seashores'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'4',
#       u'value': u'Conservation of Resources'},
#      {u'is_major': u'N',
#       u'name': u'persons',
#       u'rank': u'5',
#       u'value': u'Obama, Malia'},
#      {u'is_major': u'N',
#       u'name': u'persons',
#       u'rank': u'6',
#       u'value': u'Obama, Sasha'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'7',
#       u'value': u'United States Politics and Government'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'8',
#       u'value': u'Monuments and Memorials (Structures)'},
#      {u'is_major': u'N',
#       u'name': u'organizations',
#       u'rank': u'9',
#       u'value': u'Natural Resources Defense Council'},
#      {u'is_major': u'N',
#       u'name': u'glocations',
#       u'rank': u'10',
#       u'value': u'Carlsbad (Calif)'}],
#     u'lead_paragraph': u'Administration officials said the trip was intended in part to highlight the extraordinary economic benefits of national parks in their centennial year.',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2016/06/18/us/18obama-web3/18obama-web3-thumbWide.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2016/06/18/us/18obama-web3/18obama-web3-thumbWide.jpg',
#       u'width': 190},
#      {u'height': 446,
#       u'legacy': {u'xlarge': u'images/2016/06/18/us/18obama-web3/18obama-web3-articleLarge.jpg',
#        u'xlargeheight': u'446',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2016/06/18/us/18obama-web3/18obama-web3-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2016/06/18/us/18obama-web3/18obama-web3-thumbStandard.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2016/06/18/us/18obama-web3/18obama-web3-thumbStandard.jpg',
#       u'width': 75}],
#     u'news_desk': u'National',
#     u'print_page': u'11',
#     u'pub_date': u'2016-06-18T00:00:00Z',
#     u'section_name': u'U.S.',
#     u'slideshow_credits': None,
#     u'snippet': u'Administration officials said the trip was intended in part to highlight the extraordinary economic benefits of national parks in their centennial year.',
#     u'source': u'The New York Times',
#     u'subsection_name': u'Politics',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/2016/06/18/us/politics/obama-family-to-vacation-at-yosemite-and-carlsbad-parks.html',
#     u'word_count': u'576'},
#    {u'_id': u'5771fbff38f0d82529b0b457',
#     u'abstract': None,
#     u'blog': [],
#     u'byline': {u'organization': u'THE ASSOCIATED PRESS',
#      u'original': u'By THE ASSOCIATED PRESS',
#      u'person': []},
#     u'document_type': u'article',
#     u'headline': {u'main': u'Michelle Obama Stresses Girls\u2019 Education in Visit to Liberia'},
#     u'keywords': [{u'is_major': u'N',
#       u'name': u'persons',
#       u'rank': u'1',
#       u'value': u'Obama, Michelle'},
#      {u'is_major': u'N',
#       u'name': u'glocations',
#       u'rank': u'2',
#       u'value': u'Liberia'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'3',
#       u'value': u'Women and Girls'},
#      {u'is_major': u'N',
#       u'name': u'glocations',
#       u'rank': u'4',
#       u'value': u'Africa'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'5',
#       u'value': u'Education'}],
#     u'lead_paragraph': u'The first lady, whose trip includes stops in Morocco and Spain, urged Liberian teenagers to keep fighting to stay in school.',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2016/06/28/pageoneplus/SUB-A2-OBAMA/SUB-A2-OBAMA-thumbWide.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2016/06/28/pageoneplus/SUB-A2-OBAMA/SUB-A2-OBAMA-thumbWide.jpg',
#       u'width': 190},
#      {u'height': 430,
#       u'legacy': {u'xlarge': u'images/2016/06/28/pageoneplus/SUB-A2-OBAMA/SUB-A2-OBAMA-articleLarge.jpg',
#        u'xlargeheight': u'430',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2016/06/28/pageoneplus/SUB-A2-OBAMA/SUB-A2-OBAMA-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2016/06/28/pageoneplus/SUB-A2-OBAMA/SUB-A2-OBAMA-thumbStandard.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2016/06/28/pageoneplus/SUB-A2-OBAMA/SUB-A2-OBAMA-thumbStandard.jpg',
#       u'width': 75}],
#     u'news_desk': u'Foreign',
#     u'print_page': None,
#     u'pub_date': u'2016-06-28T00:00:00Z',
#     u'section_name': u'World',
#     u'slideshow_credits': None,
#     u'snippet': u'The first lady, whose trip includes stops in Morocco and Spain, urged Liberian teenagers to keep fighting to stay in school.',
#     u'source': u'The New York Times',
#     u'subsection_name': u'Africa',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/2016/06/28/world/africa/michelle-obama-stresses-girls-education-in-visit-to-liberia.html',
#     u'word_count': u'306'},
#    {u'_id': u'576c23b338f0d8520fd88f7c',
#     u'abstract': None,
#     u'blog': [],
#     u'byline': {u'organization': u'REUTERS',
#      u'original': u'By REUTERS',
#      u'person': []},
#     u'document_type': u'multimedia',
#     u'headline': {u'main': u'Obama: \u2018Heartbreaking\u2019 Immigration Vote'},
#     u'keywords': [{u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'1',
#       u'value': u'Immigration and Emigration'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'2',
#       u'value': u'Law and Legislation'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'3',
#       u'value': u'United States Politics and Government'},
#      {u'is_major': u'N',
#       u'name': u'organizations',
#       u'rank': u'4',
#       u'value': u'Supreme Court (US)'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'5',
#       u'value': u'Illegal Immigration'},
#      {u'is_major': u'N',
#       u'name': u'persons',
#       u'rank': u'6',
#       u'value': u'Obama, Barack'}],
#     u'lead_paragraph': u'The president spoke after the 4-4 ruling by the Supreme Court on Thursday that deals a blow to his plan to spare millions of illegal immigrants from deportation.',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2016/06/24/us/24OBAMA2-web/24OBAMA2-web-thumbWide.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2016/06/24/us/24OBAMA2-web/24OBAMA2-web-thumbWide.jpg',
#       u'width': 190},
#      {u'height': 400,
#       u'legacy': {u'xlarge': u'images/2016/06/24/us/24OBAMA2-web/24OBAMA2-web-articleLarge.jpg',
#        u'xlargeheight': u'400',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2016/06/24/us/24OBAMA2-web/24OBAMA2-web-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2016/06/24/us/24OBAMA2-web/24OBAMA2-web-thumbStandard.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2016/06/24/us/24OBAMA2-web/24OBAMA2-web-thumbStandard.jpg',
#       u'width': 75}],
#     u'news_desk': u'U.S. / Politics',
#     u'print_page': None,
#     u'pub_date': u'2016-06-23T13:59:50Z',
#     u'section_name': u'U.S.',
#     u'slideshow_credits': None,
#     u'snippet': u'The president spoke after the 4-4 ruling by the Supreme Court on Thursday that deals a blow to his plan to spare millions of illegal immigrants from deportation.',
#     u'source': u'Reuters',
#     u'subsection_name': u'Politics',
#     u'type_of_material': u'Video',
#     u'web_url': u'http://www.nytimes.com/video/us/politics/100000004490066/obama-heartbreaking-immigration-vote.html',
#     u'word_count': u'28'},
#    {u'_id': u'576bbdb838f0d83413c93ee3',
#     u'abstract': None,
#     u'blog': [],
#     u'byline': {u'original': u'By MICHAEL D. SHEAR',
#      u'person': [{u'firstname': u'Michael',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'}]},
#     u'document_type': u'article',
#     u'headline': {u'main': u'Obama Begins West Coast Trip With Business Conference'},
#     u'keywords': [{u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'1',
#       u'value': u'United States Politics and Government'},
#      {u'is_major': u'N',
#       u'name': u'persons',
#       u'rank': u'2',
#       u'value': u'Obama, Barack'},
#      {u'is_major': u'N',
#       u'name': u'glocations',
#       u'rank': u'3',
#       u'value': u'Silicon Valley (Calif)'}],
#     u'lead_paragraph': u'President Obama will travel to the Bay Area for a summit meeting on Thursday, before speaking with Mark Zuckerberg of Facebook and heading to Seattle.',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2016/06/23/us/23fdnl-obama/23fdnl-obama-thumbWide.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2016/06/23/us/23fdnl-obama/23fdnl-obama-thumbWide.jpg',
#       u'width': 190},
#      {u'height': 400,
#       u'legacy': {u'xlarge': u'images/2016/06/23/us/23fdnl-obama/23fdnl-obama-articleLarge.jpg',
#        u'xlargeheight': u'400',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2016/06/23/us/23fdnl-obama/23fdnl-obama-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2016/06/23/us/23fdnl-obama/23fdnl-obama-thumbStandard.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2016/06/23/us/23fdnl-obama/23fdnl-obama-thumbStandard.jpg',
#       u'width': 75}],
#     u'news_desk': u'National',
#     u'print_page': None,
#     u'pub_date': u'2016-06-24T00:00:00Z',
#     u'section_name': u'U.S.',
#     u'slideshow_credits': None,
#     u'snippet': u'President Obama will travel to the Bay Area for a summit meeting on Thursday, before speaking with Mark Zuckerberg of Facebook and heading to Seattle.',
#     u'source': u'The New York Times',
#     u'subsection_name': u'Politics',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/2016/06/24/us/politics/obama-global-entrepreneurship-summit.html',
#     u'word_count': u'177'},
#    {u'_id': u'576d2f0738f0d8520fd892ee',
#     u'abstract': u"Pres Obama, in first public response to Brexit vote, says special relationship between United States and Great Britain will continue and that European Union will remain important partner; acknowledges that exit highlights ongoing challenges of globalization; vote deals blow to Obama's vision of open and connected world.",
#     u'blog': [],
#     u'byline': {u'contributor': u'Mark Landler contributed reporting from Washington',
#      u'original': u'By JULIE HIRSCHFELD DAVIS and MARK LANDLER',
#      u'person': [{u'firstname': u'Julie',
#        u'lastname': u'DAVIS',
#        u'middlename': u'Hirschfeld',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'},
#       {u'firstname': u'Mark',
#        u'lastname': u'LANDLER',
#        u'organization': u'',
#        u'rank': 2,
#        u'role': u'reported'}]},
#     u'document_type': u'article',
#     u'headline': {u'main': u'Obama Says \u2018Special Relationship\u2019 With Britain Will Endure',
#      u'print_headline': u'Obama Acknowledges Loss but Says \u2018Special Relationship\u2019 Will Continue'},
#     u'keywords': [{u'is_major': u'Y',
#       u'name': u'persons',
#       u'rank': u'1',
#       u'value': u'Obama, Barack'},
#      {u'is_major': u'Y',
#       u'name': u'glocations',
#       u'rank': u'2',
#       u'value': u'Great Britain'},
#      {u'is_major': u'Y',
#       u'name': u'organizations',
#       u'rank': u'3',
#       u'value': u'European Union'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'4',
#       u'value': u'United States International Relations'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'5',
#       u'value': u'Great Britain Withdrawal from EU (Brexit)'},
#      {u'is_major': u'N',
#       u'name': u'organizations',
#       u'rank': u'6',
#       u'value': u'Stanford University'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'7',
#       u'value': u'Referendums'}],
#     u'lead_paragraph': u'The vote by Britons to leave the European Union threw a shadow over the technology-friendly president\u2019s trip to the Global Entrepreneurship Summit at Stanford University.',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2016/06/25/us/25prexy-web/25prexy-web-thumbWide.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2016/06/25/us/25prexy-web/25prexy-web-thumbWide.jpg',
#       u'width': 190},
#      {u'height': 400,
#       u'legacy': {u'xlarge': u'images/2016/06/25/us/25prexy-web/25prexy-web-articleLarge.jpg',
#        u'xlargeheight': u'400',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2016/06/25/us/25prexy-web/25prexy-web-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2016/06/25/us/25prexy-web/25prexy-web-thumbStandard.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2016/06/25/us/25prexy-web/25prexy-web-thumbStandard.jpg',
#       u'width': 75}],
#     u'news_desk': u'Foreign',
#     u'print_page': u'11',
#     u'pub_date': u'2016-06-25T00:00:00Z',
#     u'section_name': u'World',
#     u'slideshow_credits': None,
#     u'snippet': u'The vote by Britons to leave the European Union threw a shadow over the technology-friendly president\u2019s trip to the Global Entrepreneurship Summit at Stanford University.',
#     u'source': u'The New York Times',
#     u'subsection_name': u'Europe',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/2016/06/25/world/brexit-obama.html',
#     u'word_count': u'1117'}],
#   u'meta': {u'hits': 13031, u'offset': 0, u'time': 163}},
#  u'status': u'OK'}

# %%
def parse_articles(articles):
    '''
    This function takes in a response to the NYT api and parses
    the articles into a list of dictionaries
    '''
    news = []
    for i in articles['response']['docs']:
        dic = {}
        dic['id'] = i['_id']
        if i['abstract'] is not None:
            dic['abstract'] = i['abstract'].encode("utf8")
        dic['headline'] = i['headline']['main'].encode("utf8")
        dic['desk'] = i['news_desk']
        dic['date'] = i['pub_date'][0:10] # cutting time of day.
        dic['section'] = i['section_name']
        if i['snippet'] is not None:
            dic['snippet'] = i['snippet'].encode("utf8")
        dic['source'] = i['source']
        dic['type'] = i['type_of_material']
        dic['url'] = i['web_url']
        dic['word_count'] = i['word_count']
        # locations
        locations = []
        for x in range(0,len(i['keywords'])):
            if 'glocations' in i['keywords'][x]['name']:
                locations.append(i['keywords'][x]['value'])
        dic['locations'] = locations
        # subject
        subjects = []
        for x in range(0,len(i['keywords'])):
            if 'subject' in i['keywords'][x]['name']:
                subjects.append(i['keywords'][x]['value'])
        dic['subjects'] = subjects   
        news.append(dic)
    return(news)

# %%
parse_articles(articles)
# Out:
# [{'date': u'2016-07-03',
#   'desk': u'National',
#   'headline': 'Obama After Dark: The Precious Hours Alone',
#   'id': u'57776e4d38f0d81f396c0545',
#   'locations': [],
#   'section': u'U.S.',
#   'snippet': 'President Obama has come to consider the solitary hours after dark as essential as his time in the Oval Office. Barely getting five hours of sleep a night, he considers the time alone more important.',
#   'source': u'The New York Times',
#   'subjects': [u'United States Politics and Government',
#    u'White House Building (Washington, DC)'],
#   'type': u'News',
#   'url': u'http://www.nytimes.com/2016/07/03/us/politics/obama-after-dark-the-precious-hours-alone.html',
#   'word_count': u'1825'},
#  {'abstract': 'Tod Williams and Billie Tsien, husband-and-wife modernist architecture team known for work on prominent cultural institutions, are selected to design Barack H Obama Presidential Library and Museum in Chicago.',
#   'date': u'2016-07-01',
#   'desk': u'National',
#   'headline': 'Obama Picks New York Architects to Design Presidential Library',
#   'id': u'5775966f38f0d87c9d837961',
#   'locations': [u'United States', u'Chicago (Ill)'],
#   'section': u'U.S.',
#   'snippet': 'The president and his wife, Michelle, spent months poring over proposals for the project and meeting with prospective architects at the White House',
#   'source': u'The New York Times',
#   'subjects': [u'Architecture',
#    u'United States Politics and Government',
#    u'Libraries and Librarians'],
#   'type': u'News',
#   'url': u'http://www.nytimes.com/2016/07/01/us/politics/obama-picks-new-york-architects-to-design-presidential-library.html',
#   'word_count': u'635'},
#  {'abstract': 'White House Letter; Pres Obama relishes opportunity to host Cleveland Cavaliers, 2016 NBA champions, before he leaves office in January; admits welcoming championship sports teams to White House is one of his favorite presidential duties. ',
#   'date': u'2016-06-27',
#   'desk': u'National',
#   'headline': 'Cleveland Cavaliers Join Obama\xe2\x80\x99s To-Do List. He Loves This Part of the Job.',
#   'id': u'5770517038f0d8170405485f',
#   'locations': [u'Washington (DC)'],
#   'section': u'U.S.',
#   'snippet': 'Welcoming championship sports teams to the White House has been one of President Obama\xe2\x80\x99s favorite tasks. It might have even challenged the pleasures of Air Force One \xe2\x80\x94 if every winner had come from Chicago.',
#   'source': u'The New York Times',
#   'subjects': [u'Athletics and Sports',
#    u'Basketball',
#    u'Presidents and Presidency (US)',
#    u'White House Building (Washington, DC)'],
#   'type': u'News',
#   'url': u'http://www.nytimes.com/2016/06/27/us/politics/cleveland-cavaliers-join-obamas-to-do-list-he-loves-this-part-of-the-job.html',
#   'word_count': u'1085'},
#  {'abstract': "Supreme Court deadlocks 4-4 to leave in place appeals court ruling blocking Pres Obama's ambitious plan to shield undocumented immigrants from deportation; nine-word ruling ruling will have many consequences, and is likely to intensify debate over nation's immigration policy and presidential authority.  ",
#   'date': u'2016-06-24',
#   'desk': u'National',
#   'headline': 'Supreme Court Tie Blocks Obama Immigration Plan',
#   'id': u'576bf65238f0d83413c93fa4',
#   'locations': [u'Texas'],
#   'section': u'U.S.',
#   'snippet': 'The 4-4 tie dealt a sharp blow to an ambitious program that the president had hoped would become one of his central legacies.',
#   'source': u'The New York Times',
#   'subjects': [u'Immigration and Emigration',
#    u'Law and Legislation',
#    u'Deportation',
#    u'Illegal Immigration',
#    u'Decisions and Verdicts'],
#   'type': u'News',
#   'url': u'http://www.nytimes.com/2016/06/24/us/supreme-court-immigration-obama-dapa.html',
#   'word_count': u'1424'},
#  {'date': u'2016-07-02',
#   'desk': u'Letters',
#   'headline': 'Obama as the First Black President',
#   'id': u'5776b13138f0d81f396c03c5',
#   'locations': [],
#   'section': u'Opinion',
#   'snippet': 'Readers disagree with a Sunday Review writer who said the president failed to do enough to address race issues and \xe2\x80\x9clessen black suffering.\xe2\x80\x9d',
#   'source': u'The New York Times',
#   'subjects': [u'Blacks'],
#   'type': u'Letter',
#   'url': u'http://www.nytimes.com/2016/07/02/opinion/obama-as-the-first-black-president.html',
#   'word_count': u'588'},
#  {'abstract': "Pres Obama vacations with his family in Yosemite National Park, where they visit Carlsbad Caverns; series of Obama family vacations to national parks are intended to highlight benefits of protecting wilderness land, part of Obama administration's legacy on conservation.",
#   'date': u'2016-06-18',
#   'desk': u'National',
#   'headline': 'President Obama and Family Tour \xe2\x80\x98Cool\xe2\x80\x99 Carlsbad Caverns',
#   'id': u'5763eab438f0d83da36e0716',
#   'locations': [u'Yosemite National Park (Calif)', u'Carlsbad (Calif)'],
#   'section': u'U.S.',
#   'snippet': 'Administration officials said the trip was intended in part to highlight the extraordinary economic benefits of national parks in their centennial year.',
#   'source': u'The New York Times',
#   'subjects': [u'National Parks, Monuments and Seashores',
#    u'Conservation of Resources',
#    u'United States Politics and Government',
#    u'Monuments and Memorials (Structures)'],
#   'type': u'News',
#   'url': u'http://www.nytimes.com/2016/06/18/us/politics/obama-family-to-vacation-at-yosemite-and-carlsbad-parks.html',
#   'word_count': u'576'},
#  {'date': u'2016-06-28',
#   'desk': u'Foreign',
#   'headline': 'Michelle Obama Stresses Girls\xe2\x80\x99 Education in Visit to Liberia',
#   'id': u'5771fbff38f0d82529b0b457',
#   'locations': [u'Liberia', u'Africa'],
#   'section': u'World',
#   'snippet': 'The first lady, whose trip includes stops in Morocco and Spain, urged Liberian teenagers to keep fighting to stay in school.',
#   'source': u'The New York Times',
#   'subjects': [u'Women and Girls', u'Education'],
#   'type': u'News',
#   'url': u'http://www.nytimes.com/2016/06/28/world/africa/michelle-obama-stresses-girls-education-in-visit-to-liberia.html',
#   'word_count': u'306'},
#  {'date': u'2016-06-23',
#   'desk': u'U.S. / Politics',
#   'headline': 'Obama: \xe2\x80\x98Heartbreaking\xe2\x80\x99 Immigration Vote',
#   'id': u'576c23b338f0d8520fd88f7c',
#   'locations': [],
#   'section': u'U.S.',
#   'snippet': 'The president spoke after the 4-4 ruling by the Supreme Court on Thursday that deals a blow to his plan to spare millions of illegal immigrants from deportation.',
#   'source': u'Reuters',
#   'subjects': [u'Immigration and Emigration',
#    u'Law and Legislation',
#    u'United States Politics and Government',
#    u'Illegal Immigration'],
#   'type': u'Video',
#   'url': u'http://www.nytimes.com/video/us/politics/100000004490066/obama-heartbreaking-immigration-vote.html',
#   'word_count': u'28'},
#  {'date': u'2016-06-24',
#   'desk': u'National',
#   'headline': 'Obama Begins West Coast Trip With Business Conference',
#   'id': u'576bbdb838f0d83413c93ee3',
#   'locations': [u'Silicon Valley (Calif)'],
#   'section': u'U.S.',
#   'snippet': 'President Obama will travel to the Bay Area for a summit meeting on Thursday, before speaking with Mark Zuckerberg of Facebook and heading to Seattle.',
#   'source': u'The New York Times',
#   'subjects': [u'United States Politics and Government'],
#   'type': u'News',
#   'url': u'http://www.nytimes.com/2016/06/24/us/politics/obama-global-entrepreneurship-summit.html',
#   'word_count': u'177'},
#  {'abstract': "Pres Obama, in first public response to Brexit vote, says special relationship between United States and Great Britain will continue and that European Union will remain important partner; acknowledges that exit highlights ongoing challenges of globalization; vote deals blow to Obama's vision of open and connected world.",
#   'date': u'2016-06-25',
#   'desk': u'Foreign',
#   'headline': 'Obama Says \xe2\x80\x98Special Relationship\xe2\x80\x99 With Britain Will Endure',
#   'id': u'576d2f0738f0d8520fd892ee',
#   'locations': [u'Great Britain'],
#   'section': u'World',
#   'snippet': 'The vote by Britons to leave the European Union threw a shadow over the technology-friendly president\xe2\x80\x99s trip to the Global Entrepreneurship Summit at Stanford University.',
#   'source': u'The New York Times',
#   'subjects': [u'United States International Relations',
#    u'Great Britain Withdrawal from EU (Brexit)',
#    u'Referendums'],
#   'type': u'News',
#   'url': u'http://www.nytimes.com/2016/06/25/world/brexit-obama.html',
#   'word_count': u'1117'}]
